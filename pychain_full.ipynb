# %%
# Imports
import streamlit as st
from dataclasses import dataclass
from typing import Any, List
import datetime as datetime
import pandas as pd
import hashlib
# Out:
# 2022-08-04 20:33:30.873 INFO    numexpr.utils: NumExpr defaulting to 8 threads.
# 2022-08-04 20:33:31.386 WARNING matplotlib:
# Bad key savefig.frameon in file /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 421 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.3/matplotlibrc.template
# or from the matplotlib source distribution
# 2022-08-04 20:33:31.386 WARNING matplotlib:
# Bad key verbose.level in file /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 472 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.3/matplotlibrc.template
# or from the matplotlib source distribution
# 2022-08-04 20:33:31.386 WARNING matplotlib:
# Bad key verbose.fileo in file /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 473 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.3/matplotlibrc.template
# or from the matplotlib source distribution
# 2022-08-04 20:33:31.387 WARNING matplotlib.style.core: In /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# 2022-08-04 20:33:31.387 WARNING matplotlib.style.core: In /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# 2022-08-04 20:33:31.387 WARNING matplotlib.style.core: In /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# 2022-08-04 20:33:31.387 WARNING matplotlib.style.core: In /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# 2022-08-04 20:33:31.388 WARNING matplotlib.style.core: In /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# 2022-08-04 20:33:31.388 WARNING matplotlib.style.core: In /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# 2022-08-04 20:33:31.388 WARNING matplotlib.style.core: In /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# 2022-08-04 20:33:31.388 WARNING matplotlib.style.core: In /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
# Step 1:
# Create a Record Data Class

# Define a new Python data class named `Record`. Give this new class a
# formalized data structure that consists of the `sender`, `receiver`, and
# `amount` attributes. To do so, complete the following steps:
# 1. Define a new class named `Record`.
# 2. Add the `@dataclass` decorator immediately before the `Record` class
# definition.
@dataclass
class Record:
    # 3. Add an attribute named `sender` of type `str`.
    sender: str
    # 4. Add an attribute named `receiver` of type `str`.
    receiver: str
    # 5. Add an attribute named `amount` of type `float`.
    amount: float

# %%
# Step 2:
# Modify the Existing Block Data Class to Store Record Data

# Rename the `data` attribute in your `Block` class to `record`, and then set
# it to use an instance of the new `Record` class that you created in the
# previous section. To do so, complete the following steps:
# 1. In the `Block` class, rename the `data` attribute to `record`.
# 2. Set the data type of the `record` attribute to `Record`.


@dataclass
class Block:

    # @TODO
    # Rename the `data` attribute to `record`, and set the data type to `Record`
    record: Record

    creator_id: int
    prev_hash: str = "0"
    timestamp: str = datetime.datetime.utcnow().strftime("%H:%M:%S")
    nonce: int = 0

    def hash_block(self):
        sha = hashlib.sha256()

        record = str(self.record).encode()
        sha.update(record)

        creator_id = str(self.creator_id).encode()
        sha.update(creator_id)

        timestamp = str(self.timestamp).encode()
        sha.update(timestamp)

        prev_hash = str(self.prev_hash).encode()
        sha.update(prev_hash)

        nonce = str(self.nonce).encode()
        sha.update(nonce)

        return sha.hexdigest()


@dataclass
class PyChain:
    chain: List[Block]
    difficulty: int = 4

    def proof_of_work(self, block):

        calculated_hash = block.hash_block()

        num_of_zeros = "0" * self.difficulty

        while not calculated_hash.startswith(num_of_zeros):

            block.nonce += 1

            calculated_hash = block.hash_block()

        print("Wining Hash", calculated_hash)
        return block

    def add_block(self, candidate_block):
        block = self.proof_of_work(candidate_block)
        self.chain += [block]

    def is_valid(self):
        block_hash = self.chain[0].hash_block()

        for block in self.chain[1:]:
            if block_hash != block.prev_hash:
                print("Blockchain is invalid!")
                return False

            block_hash = block.hash_block()

        print("Blockchain is Valid")
        return True

# Streamlit Code

# Adds the cache decorator for Streamlit


@st.cache(allow_output_mutation=True)
def setup():
    print("Initializing Chain")
    return PyChain([Block("Genesis", 0)])


st.markdown("# PyChain")
st.markdown("## Store a Transaction Record in the PyChain")

pychain = setup()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     367             # Hash the input
# --> 368             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     369
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     633             assert code is not None
# --> 634             if self._file_should_be_hashed(code.co_filename):
#     635                 context = _get_context(obj)
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     409         return file_util.file_is_in_folder_glob(
# --> 410             filepath, self._get_main_script_directory()
#     411         ) or file_util.file_in_pythonpath(filepath)
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _get_main_script_directory()
#     720         # script path in ScriptRunner.
# --> 721         main_path = __main__.__file__
#     722         return str(os.path.dirname(main_path))
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# /var/folders/l8/h_kl8b_9545cnphmprhv7_0c0000gn/T/ipykernel_26057/3979010923.py in <module>
#      93 st.markdown("## Store a Transaction Record in the PyChain")
#      94
# ---> 95 pychain = setup()
#      96
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/caching.py in wrapped_func(*args, **kwargs)
#     571         if show_spinner:
#     572             with st.spinner(message):
# --> 573                 return get_or_create_cached_value()
#     574         else:
#     575             return get_or_create_cached_value()
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/caching.py in get_or_create_cached_value()
#     496                 # If we generated the key earlier we would only hash those
#     497                 # globals by name, and miss changes in their code or value.
# --> 498                 cache_key = _hash_func(func, hash_funcs)
#     499
#     500             # First, get the cache that's attached to this function.
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/caching.py in _hash_func(func, hash_funcs)
#     627         hash_funcs=hash_funcs,
#     628         hash_reason=HashReason.CACHING_FUNC_BODY,
# --> 629         hash_source=func,
#     630     )
#     631     cache_key = func_hasher.hexdigest()
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     114
#     115     ch = _CodeHasher(hash_funcs)
# --> 116     ch.update(hasher, val, context)
#     117
#     118
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in update(self, hasher, obj, context)
#     391     def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     392         """Update the provided hasher with the hash of an object."""
# --> 393         b = self.to_bytes(obj, context)
#     394         hasher.update(b)
#     395
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     380
#     381         except BaseException as e:
# --> 382             raise InternalHashError(e, obj)
#     383
#     384         finally:
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     366         try:
#     367             # Hash the input
# --> 368             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     369
#     370             # Hmmm... It's possible that the size calculation is wrong. When we
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     632             code = getattr(obj, "__code__", None)
#     633             assert code is not None
# --> 634             if self._file_should_be_hashed(code.co_filename):
#     635                 context = _get_context(obj)
#     636                 defaults = getattr(obj, "__defaults__", None)
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     408             return False
#     409         return file_util.file_is_in_folder_glob(
# --> 410             filepath, self._get_main_script_directory()
#     411         ) or file_util.file_in_pythonpath(filepath)
#     412
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _get_main_script_directory()
#     719         # This works because we set __main__.__file__ to the
#     720         # script path in ScriptRunner.
# --> 721         main_path = __main__.__file__
#     722         return str(os.path.dirname(main_path))
#     723
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `setup()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function setup at 0x7f80e4267290>
# ```
#
# Please see the `hash_funcs` [documentation]
# (https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.

# %%
# Out:
# 2022-08-04 20:43:25.026
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/oliviaheitz/opt/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     367             # Hash the input
# --> 368             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     369
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     633             assert code is not None
# --> 634             if self._file_should_be_hashed(code.co_filename):
#     635                 context = _get_context(obj)
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     409         return file_util.file_is_in_folder_glob(
# --> 410             filepath, self._get_main_script_directory()
#     411         ) or file_util.file_in_pythonpath(filepath)
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _get_main_script_directory()
#     720         # script path in ScriptRunner.
# --> 721         main_path = __main__.__file__
#     722         return str(os.path.dirname(main_path))
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# /var/folders/l8/h_kl8b_9545cnphmprhv7_0c0000gn/T/ipykernel_26057/1802741971.py in <module>
#      13 st.markdown("## Store a Transaction Record in the PyChain")
#      14
# ---> 15 pychain = setup()
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/caching.py in wrapped_func(*args, **kwargs)
#     571         if show_spinner:
#     572             with st.spinner(message):
# --> 573                 return get_or_create_cached_value()
#     574         else:
#     575             return get_or_create_cached_value()
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/caching.py in get_or_create_cached_value()
#     496                 # If we generated the key earlier we would only hash those
#     497                 # globals by name, and miss changes in their code or value.
# --> 498                 cache_key = _hash_func(func, hash_funcs)
#     499
#     500             # First, get the cache that's attached to this function.
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/caching.py in _hash_func(func, hash_funcs)
#     627         hash_funcs=hash_funcs,
#     628         hash_reason=HashReason.CACHING_FUNC_BODY,
# --> 629         hash_source=func,
#     630     )
#     631     cache_key = func_hasher.hexdigest()
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     114
#     115     ch = _CodeHasher(hash_funcs)
# --> 116     ch.update(hasher, val, context)
#     117
#     118
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in update(self, hasher, obj, context)
#     391     def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     392         """Update the provided hasher with the hash of an object."""
# --> 393         b = self.to_bytes(obj, context)
#     394         hasher.update(b)
#     395
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     380
#     381         except BaseException as e:
# --> 382             raise InternalHashError(e, obj)
#     383
#     384         finally:
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     366         try:
#     367             # Hash the input
# --> 368             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     369
#     370             # Hmmm... It's possible that the size calculation is wrong. When we
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     632             code = getattr(obj, "__code__", None)
#     633             assert code is not None
# --> 634             if self._file_should_be_hashed(code.co_filename):
#     635                 context = _get_context(obj)
#     636                 defaults = getattr(obj, "__defaults__", None)
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     408             return False
#     409         return file_util.file_is_in_folder_glob(
# --> 410             filepath, self._get_main_script_directory()
#     411         ) or file_util.file_in_pythonpath(filepath)
#     412
#
# ~/opt/anaconda3/envs/dev/lib/python3.7/site-packages/streamlit/legacy_caching/hashing.py in _get_main_script_directory()
#     719         # This works because we set __main__.__file__ to the
#     720         # script path in ScriptRunner.
# --> 721         main_path = __main__.__file__
#     722         return str(os.path.dirname(main_path))
#     723
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `setup()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function setup at 0x7f80e416fef0>
# ```
#
# Please see the `hash_funcs` [documentation]
# (https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.
